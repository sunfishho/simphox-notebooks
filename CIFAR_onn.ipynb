# %% [markdown]
# # Scalability of *in situ* backpropagation
#
# In this notebook, we explore the scalability of *in situ* backpropagation as it pertains to the tradeoff between noise and energy efficiency and latency of photonic devices.
# - As far as scalability of the photonic advantage, we do our best to incorporate all of the different elements that contribute to the total energy consumption in the hybrid photonic neural network design, dominated by optoelectronic conversions and signal amplification, and any assumptions for this calculation are provided in the main text and/or Supplementary Material of the paper.
# - As far as noise error scaling, we explore the tradeoffs of various errors (e.g., systematic in the various photonic elements and random noise at the photodetector). We then perform large-scale simulations on MNIST data to show that realistic problems can be solved using our approach in the presence of error.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pip install simphox
# Out:
# Requirement already satisfied: simphox in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/simphox-0.0.1a8-py3.10.egg (0.0.1a8)
# Requirement already satisfied: numpy in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages (from simphox) (1.24.3)
# Requirement already satisfied: scipy in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages (from simphox) (1.10.1)
# Requirement already satisfied: pandas in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/pandas-2.0.2-py3.10-macosx-12-arm64.egg (from simphox) (2.0.2)
# Requirement already satisfied: jaxlib in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/jaxlib-0.4.12-py3.10-macosx-12-arm64.egg (from simphox) (0.4.12)
# Requirement already satisfied: jax in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg (from simphox) (0.4.12)
# Requirement already satisfied: scikit-image in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/scikit_image-0.21.0-py3.10-macosx-12-arm64.egg (from simphox) (0.21.0)
# Requirement already satisfied: pydantic in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/pydantic-2.0b3-py3.10.egg (from simphox) (2.0b3)
# Requirement already satisfied: xarray in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/xarray-2023.5.0-py3.10.egg (from simphox) (2023.5.0)
# Requirement already satisfied: dm-haiku in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/dm_haiku-0.0.9-py3.10.egg (from simphox) (0.0.9)
# Requirement already satisfied: absl-py in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages (from simphox) (1.4.0)
# Requirement already satisfied: jmp>=0.0.2 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/jmp-0.0.4-py3.10.egg (from dm-haiku->simphox) (0.0.4)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/tabulate-0.9.0-py3.10.egg (from dm-haiku->simphox) (0.9.0)
# Requirement already satisfied: ml_dtypes>=0.1.0 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/ml_dtypes-0.2.0-py3.10-macosx-12-arm64.egg (from jax->simphox) (0.2.0)
# Requirement already satisfied: opt_einsum in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages (from jax->simphox) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/python_dateutil-2.8.2-py3.10.egg (from pandas->simphox) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/pytz-2023.3-py3.10.egg (from pandas->simphox) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/tzdata-2023.3-py3.10.egg (from pandas->simphox) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/annotated_types-0.5.0-py3.10.egg (from pydantic->simphox) (0.5.0)
# Requirement already satisfied: pydantic-core==0.39.0 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/pydantic_core-0.39.0-py3.10-macosx-12-arm64.egg (from pydantic->simphox) (0.39.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages (from pydantic->simphox) (4.6.3)
# Requirement already satisfied: networkx>=2.8 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/networkx-3.1-py3.10.egg (from scikit-image->simphox) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/Pillow-9.5.0-py3.10-macosx-12-arm64.egg (from scikit-image->simphox) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/imageio-2.31.1-py3.10.egg (from scikit-image->simphox) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/tifffile-2023.4.12-py3.10.egg (from scikit-image->simphox) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/PyWavelets-1.4.1-py3.10-macosx-12-arm64.egg (from scikit-image->simphox) (1.4.1)
# Requirement already satisfied: packaging>=21 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages (from scikit-image->simphox) (23.1)
# Requirement already satisfied: lazy_loader>=0.2 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages/lazy_loader-0.2-py3.10.egg (from scikit-image->simphox) (0.2)
# Requirement already satisfied: six>=1.5 in /Users/matthewho/Photonic_computing/photonics_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->simphox) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from simphox.circuit import rectangular
from simphox.utils import random_unitary
from jax import jit
import jax
import numpy as np
import jax.numpy as jnp
from mlflow import log_metric, log_param, log_artifacts
import wandb

import holoviews as hv
hv.extension('bokeh')

from dataclasses import dataclass

jax.config.update('jax_platform_name', 'cpu')  # change to cpu if not using gpu (slower!)
jax.config.update("jax_enable_x64", False)
jax.devices()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# [CpuDevice(id=0)]

# %%
mesh = rectangular(random_unitary(256).astype(np.complex64)) # use this object to get the necessary functions
mesh_0 = mesh
mesh_1 = rectangular(random_unitary(256).astype(np.complex64))
mesh_2 = rectangular(random_unitary(256).astype(np.complex64))

# %%
from PIL import Image, ImageFilter

# %%
from keras.datasets import cifar10
from utils import CIFARTenDataProcessor

cifar_dp = CIFARTenDataProcessor()
data = cifar_dp.fourier(8)

# %%
print(data.y_test.shape)
# Out:
# (10000, 10)

# %%
from jax import grad
from jax import vjp

prop_jit = jit(mesh.propagate_matrix_fn(use_jax=True, explicit=True))
prop = mesh.propagate_matrix_fn(use_jax=False, explicit=True)
matrix_fn = mesh.matrix_fn(use_jax=True)
ones = jnp.ones(256, dtype=jnp.complex64)
tr = lambda u: jnp.abs(u[0, 0]) ** 2
fn = lambda params: tr(matrix_fn(params))
fn_jit = jit(fn)

grad_fn = grad(fn)
grad_fn_jit = grad(fn_jit)

# %%
from jax.scipy.special import logsumexp
from jax import vmap, vjp

def dropout_softmax(outputs, num_classes: int = 10):
    return jax.nn.log_softmax(outputs[:num_classes]).astype(jnp.float32)

matrix_fn = jit(mesh.matrix_fn(use_jax=True))

def cifar_onn(params, inputs):
    # per-example predictions
    outputs = inputs
    for param in params:
        outputs = jnp.abs(matrix_fn(param, outputs))[:, 0] + 0j
    outputs = jnp.abs(outputs) ** 2
    return dropout_softmax(outputs, 10)

batched_cifar_onn = vmap(cifar_onn, in_axes=(None, 0))

# %%
@jit
def batch_loss(params, inputs, targets):
    preds = batched_cifar_onn(params, inputs)
    return -jnp.mean(preds.squeeze() * targets).real

@jit
def loss(params, inputs, targets):
    preds = cifar_onn(params, inputs)
    return -jnp.mean(preds.squeeze() * targets).real

# %%
def evaluate(params, images, targets):
    target_class = jnp.argmax(targets, axis=1)
    predicted_class = jnp.argmax(batched_cifar_onn(params, images), axis=1)
    return jnp.mean(predicted_class == target_class)

# %%
from jax.example_libraries.optimizers import adam
from tqdm.notebook import tqdm as pbar
from jax import value_and_grad

step_size = 0.001

num_iters = 1200
batch_size = 128
num_epochs = 50

x_train = jnp.array(data.x_train).astype(np.complex64)
y_train = jnp.array(data.y_train).astype(np.float32)

# %%
x_test = jnp.array(data.x_test).astype(np.complex64)
y_test = jnp.array(data.y_test).astype(np.float32)

opt_init, opt_update, get_params = adam(step_size=step_size)
init_params = [mesh_0.params, mesh_1.params, mesh_2.params]
init = opt_init(init_params)

def update_fn(i, state):
    start = (i * batch_size) % 50000
    stop = ((i + 1) * batch_size) % 50000
    v, g = value_and_grad(batch_loss)(get_params(state), x_train[start:stop], y_train[start:stop])
    return v, opt_update(i, g, state)

losses = []
opt_state = init

for epoch in range(num_epochs):
    iterator = pbar(range(x_train.shape[0]//batch_size))
    for i in iterator:
        v, opt_state = update_fn(i, opt_state)
        losses.append(v)
        iterator.set_description(f"𝓛: {v:.5f}")
    print(f"Batch size {batch_size}, epoch {epoch+1}: test accuracy is {evaluate(get_params(opt_state), x_test, y_test).item()}")
    # print(f"Train accuracy is {evaluate(get_params(opt_state), x_train, y_train).item()}")
# Out:
#   0%|          | 0/1562 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 20
#      18 iterator = pbar(range(x_train.shape[0]//batch_size))
#      19 for i in iterator:
# ---> 20     v, opt_state = update_fn(i, opt_state)
#      21     losses.append(v)
#      22     iterator.set_description(f"𝓛: {v:.5f}")
#
# Cell In[63], line 11, in update_fn(i, state)
#       9 start = (i * batch_size) % 50000
#      10 stop = ((i + 1) * batch_size) % 50000
# ---> 11 v, g = value_and_grad(batch_loss)(get_params(state), x_train[start:stop], y_train[start:stop])
#      12 return v, opt_update(i, g, state)
#
#     [... skipping hidden 1 frame]
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/api.py:723, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     721 _check_scalar(ans)
#     722 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 723 g = vjp_py(lax_internal._one(ans))
#     724 g = g[0] if isinstance(argnums, int) else g
#     725 if not has_aux:
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/tree_util.py:307, in _HashableCallableShim.__call__(self, *args, **kw)
#     306 def __call__(self, *args, **kw):
# --> 307   return self.fun(*args, **kw)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/api.py:2098, in _vjp_pullback_wrapper(name, cotangent_dtypes, cotangent_shapes, io_tree, fun, *py_args_)
#    2093   if np.shape(arg) != ct_shape:
#    2094     raise ValueError(
#    2095         f"Shape of cotangent input to vjp pullback function {np.shape(arg)} "
#    2096         "must be the same as the shape of corresponding primal input "
#    2097         f"{ct_shape}.")
# -> 2098 ans = fun(*args)
#    2099 return tree_unflatten(out_tree, ans)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/tree_util.py:307, in _HashableCallableShim.__call__(self, *args, **kw)
#     306 def __call__(self, *args, **kw):
# --> 307   return self.fun(*args, **kw)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/interpreters/ad.py:146, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     144 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     145 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 146 arg_cts = backward_pass(jaxpr, reduce_axes, True, consts, dummy_args, cts)
#     147 return map(instantiate_zeros, arg_cts)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/interpreters/ad.py:250, in backward_pass(jaxpr, reduce_axes, transform_stack, consts, primals_in, cotangents_in)
#     247   cts_out = get_primitive_transpose(eqn.primitive)(
#     248       params, call_jaxpr, invals, cts_in, cts_in_avals, reduce_axes)
#     249 elif eqn.primitive in reducing_transposes:
# --> 250   cts_out = reducing_transposes[eqn.primitive](
#     251       reduce_axes, cts_in, *invals, **eqn.params)
#     252 else:
#     253   cts_out = get_primitive_transpose(eqn.primitive)(
#     254       cts_in, *invals, **eqn.params)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/pjit.py:1665, in _pjit_transpose(reduce_axes, cts_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *primals_in)
#    1659 cts_out_treedef = cts_out_treedef_thunk()
#    1660 transpose_out_shardings = prune_type(
#    1661     ad.Zero,
#    1662     in_shardings,
#    1663     tree_unflatten(cts_out_treedef, [object()] * cts_out_treedef.num_leaves))
# -> 1665 nz_cts_out = pjit_p.bind(
#    1666     *primals_and_nz_cts_in,
#    1667     jaxpr=transpose_jaxpr,
#    1668     in_shardings=transpose_in_shardings,
#    1669     out_shardings=transpose_out_shardings,
#    1670     resource_env=resource_env,
#    1671     donated_invars=(False,) * len(primals_and_nz_cts_in),
#    1672     name=name,
#    1673     keep_unused=keep_unused,
#    1674     inline=inline)
#    1675 return tree_unflatten(cts_out_treedef, nz_cts_out)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/core.py:2652, in AxisPrimitive.bind(self, *args, **params)
#    2648 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2649                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2650 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2651              else axis_main.with_cur_sublevel())
# -> 2652 return self.bind_with_trace(top_trace, args, params)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/core.py:383, in Primitive.bind_with_trace(self, trace, args, params)
#     382 def bind_with_trace(self, trace, args, params):
# --> 383   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     384   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/core.py:790, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     789 def process_primitive(self, primitive, tracers, params):
# --> 790   return primitive.impl(*tracers, **params)
#
# File ~/Photonic_computing/photonics_env/lib/python3.10/site-packages/jax-0.4.12-py3.10.egg/jax/_src/pjit.py:1193, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1190 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1191 has_explicit_sharding = _pjit_explicit_sharding(
#    1192     in_shardings, out_shardings, None, None)
# -> 1193 return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1194                     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# KeyboardInterrupt:

# %%
batch_loss(get_params(opt_state), x_test, y_test)

# %%
print(y_test.shape)

# %%
evaluate(get_params(opt_state), x_test, y_test).item()
# Out:
# 0.09999999403953552

# %%
nplosses = np.array(losses)
with np.printoptions(threshold=np.inf):
    for i in range(np.shape(nplosses)[0]):
        print(list(enumerate(list(nplosses)))[i])
# Out:
# (0, 2.9305437)
# (1, 2.726717)
# (2, 5.6478076)
# (3, 1.8621563)
# (4, 3.2459278)
# (5, 3.2684135)
# (6, 3.6867025)
# (7, 3.5666215)
# (8, 3.5596626)
# (9, 3.2248096)
# (10, 2.8013332)
# (11, 2.2840595)
# (12, 1.996918)
# (13, 1.2190584)
# (14, 1.4562438)
# (15, 2.2973554)
# (16, 2.0406346)
# (17, 1.4686996)
# (18, 0.90041465)
# (19, 0.46402073)
# (20, 0.48684594)
# (21, 0.4515811)
# (22, 0.3670866)
# (23, 0.49838257)
# (24, 0.53109103)
# (25, 0.56680405)
# (26, 0.48217678)
# (27, 0.47321835)
# (28, 0.44252968)
# (29, 0.4761884)
# (30, 0.46418044)
# (31, 0.48402363)
# (32, 0.42657638)
# (33, 0.4178388)
# (34, 0.32926518)
# (35, 0.34380633)
# (36, 0.3090646)
# (37, 0.30316973)
# (38, 0.31185803)
# (39, 0.26745296)
# (40, 0.2859601)
# (41, 0.26100877)
# (42, 0.2632288)
# (43, 0.2426542)
# (44, 0.25743264)
# (45, 0.24395525)
# (46, 0.24674797)
# (47, 0.24287252)
# (48, 0.25196892)
# (49, 0.25118408)
# (50, 0.26236826)
# (51, 0.25949648)
# (52, 0.2514008)
# (53, 0.2588893)
# (54, 0.25276428)
# (55, 0.23597042)
# (56, 0.24162209)
# (57, 0.23566285)
# (58, 0.23749037)
# (59, 0.23579727)
# (60, 0.22970784)
# (61, 0.23952655)
# (62, 0.22622982)
# (63, 0.22684656)
# (64, 0.22559395)
# (65, 0.2262394)
# (66, 0.23142056)
# (67, 0.22533193)
# (68, 0.23047832)
# (69, 0.23695903)
# (70, 0.24162431)
# (71, 0.23769002)
# (72, 0.22583771)
# (73, 0.2301003)
# (74, 0.23264061)
# (75, 0.22115195)
# (76, 0.22811238)
# (77, 0.21458755)
# (78, 0.22780995)
# (79, 0.22870784)
# (80, 0.22185385)
# (81, 0.22810845)
# (82, 0.22532852)
# (83, 0.21254821)
# (84, 0.21819936)
# (85, 0.2267592)
# (86, 0.2222846)
# (87, 0.21363822)
# (88, 0.22039478)
# (89, 0.2312843)
# (90, 0.2291814)
# (91, 0.21921284)
# (92, 0.22950779)
# (93, 0.22212973)
# (94, 0.22542861)
# (95, 0.22539356)
# (96, 0.2304199)
# (97, 0.22816356)
# (98, 0.22575636)
# (99, 0.23480514)
# (100, 0.22924343)
# (101, 0.23219314)
# (102, 0.22788809)
# (103, 0.2193092)
# (104, 0.22559214)
# (105, 0.22554624)
# (106, 0.2210226)
# (107, 0.22528286)
# (108, 0.22756945)
# (109, 0.2226394)
# (110, 0.21662693)
# (111, 0.2234386)
# (112, 0.22757466)
# (113, 0.21840718)
# (114, 0.216886)
# (115, 0.21506815)
# (116, 0.21141696)
# (117, 0.227998)
# (118, 0.21459885)
# (119, 0.22300282)
# (120, 0.22005835)
# (121, 0.2241838)
# (122, 0.21852231)
# (123, 0.22255161)
# (124, 0.22070801)
# (125, 0.22079594)
# (126, 0.22469743)
# (127, 0.21904634)
# (128, 0.21210478)
# (129, 0.22326092)
# (130, 0.22934876)
# (131, 0.22034867)
# (132, 0.2137684)
# (133, 0.22950315)
# (134, 0.21822886)
# (135, 0.21644364)
# (136, 0.22155915)
# (137, 0.22495003)
# (138, 0.2215406)
# (139, 0.21204698)
# (140, 0.22465959)
# (141, 0.21692076)
# (142, 0.2229117)
# (143, 0.21654747)
# (144, 0.21704955)
# (145, 0.21658488)
# (146, 0.21583568)
# (147, 0.21704538)
# (148, 0.21516442)
# (149, 0.21225114)
# (150, 0.22570705)
# (151, 0.20789567)
# (152, 0.22165537)
# (153, 0.21013065)
# (154, 0.21722615)
# (155, 0.22159858)
# (156, 0.22079228)
# (157, 0.21918571)
# (158, 0.22060576)
# (159, 0.20841454)
# (160, 0.2136951)
# (161, 0.22428726)
# (162, 0.22555175)
# (163, 0.21560931)
# (164, 0.20960999)
# (165, 0.21860312)
# (166, 0.21051839)
# (167, 0.21016335)
# (168, 0.21447389)
# (169, 0.20693353)
# (170, 0.2093056)
# (171, 0.22440515)
# (172, 0.21835785)
# (173, 0.21944045)
# (174, 0.22520243)
# (175, 0.21160498)
# (176, 0.21233788)
# (177, 0.2114185)
# (178, 0.2137165)
# (179, 0.21965091)
# (180, 0.21402359)
# (181, 0.21857195)
# (182, 0.20710926)
# (183, 0.22473629)
# (184, 0.20476793)
# (185, 0.21364951)
# (186, 0.21798277)
# (187, 0.22610135)
# (188, 0.20744991)
# (189, 0.21432762)
# (190, 0.20868316)
# (191, 0.2027144)
# (192, 0.20977114)
# (193, 0.21126826)
# (194, 0.21354988)
# (195, 0.20831211)
# (196, 0.20446344)
# (197, 0.22029172)
# (198, 0.21644394)
# (199, 0.20330654)
# (200, 0.21823445)
# (201, 0.2157787)
# (202, 0.21288395)
# (203, 0.20435536)
# (204, 0.21446295)
# (205, 0.21577434)
# (206, 0.21395297)
# (207, 0.21151392)
# (208, 0.21710233)
# (209, 0.2213368)
# (210, 0.20579815)
# (211, 0.20866008)
# (212, 0.22013555)
# (213, 0.22075927)
# (214, 0.22567408)
# (215, 0.21832132)
# (216, 0.21110713)
# (217, 0.21639009)
# (218, 0.21686791)
# (219, 0.2203425)
# (220, 0.2282683)
# (221, 0.22412615)
# (222, 0.22008471)
# (223, 0.21970287)
# (224, 0.2157837)
# (225, 0.20535295)
# (226, 0.21572118)
# (227, 0.2136147)
# (228, 0.22291031)
# (229, 0.21938749)
# (230, 0.22626543)
# (231, 0.21126893)
# (232, 0.2044755)
# (233, 0.21256998)
# (234, 0.2156363)
# (235, 0.22510062)
# (236, 0.20745681)
# (237, 0.21635187)
# (238, 0.20592122)
# (239, 0.22768222)
# (240, 0.21123795)
# (241, 0.21418713)
# (242, 0.20613833)
# (243, 0.22156711)
# (244, 0.22164969)
# (245, 0.22037111)
# (246, 0.20892559)
# (247, 0.2152452)
# (248, 0.22030567)
# (249, 0.2100741)
# (250, 0.21606135)
# (251, 0.21147119)
# (252, 0.20758522)
# (253, 0.21916738)
# (254, 0.21050134)
# (255, 0.21707718)
# (256, 0.21116579)
# (257, 0.22099188)
# (258, 0.21753779)
# (259, 0.20643723)
# (260, 0.20412679)
# (261, 0.22141857)
# (262, 0.22489269)
# (263, 0.22264694)
# (264, 0.20310496)
# (265, 0.21221042)
# (266, 0.20214824)
# (267, 0.20679505)
# (268, 0.21319829)
# (269, 0.22377865)
# (270, 0.20254186)
# (271, 0.2060359)
# (272, 0.21678828)
# (273, 0.21056667)
# (274, 0.1989761)
# (275, 0.20612673)
# (276, 0.21596484)
# (277, 0.21014796)
# (278, 0.20658599)
# (279, 0.20885205)
# (280, 0.20359538)
# (281, 0.20778786)
# (282, 0.19961838)
# (283, 0.21437712)
# (284, 0.20382345)
# (285, 0.20265459)
# (286, 0.21494465)
# (287, 0.20013617)
# (288, 0.21229993)
# (289, 0.22060375)
# (290, 0.21273561)
# (291, 0.22115457)
# (292, 0.21881156)
# (293, 0.21887755)
# (294, 0.20568147)
# (295, 0.20865698)
# (296, 0.21254845)
# (297, 0.21188879)
# (298, 0.20710158)
# (299, 0.21595469)
# (300, 0.20925248)
# (301, 0.21028996)
# (302, 0.21845369)
# (303, 0.20868075)
# (304, 0.21201496)
# (305, 0.20039988)
# (306, 0.20824657)
# (307, 0.21487653)
# (308, 0.2216672)
# (309, 0.21475458)
# (310, 0.21361807)
# (311, 0.22247802)
# (312, 0.2120158)
# (313, 0.20650363)
# (314, 0.21297054)
# (315, 0.21608262)
# (316, 0.204054)
# (317, 0.19519918)
# (318, 0.21573567)
# (319, 0.21497269)
# (320, 0.21986723)
# (321, 0.21177545)
# (322, 0.21131015)
# (323, 0.21311145)
# (324, 0.21656476)
# (325, 0.20746903)
# (326, 0.1989348)
# (327, 0.21000277)
# (328, 0.21868734)
# (329, 0.22099772)
# (330, 0.20841561)
# (331, 0.20646854)
# (332, 0.2266094)
# (333, 0.2119418)
# (334, 0.21502502)
# (335, 0.20320542)
# (336, 0.21028824)
# (337, 0.20792113)
# (338, 0.20453921)
# (339, 0.22337241)
# (340, 0.19837077)
# (341, 0.20622349)
# (342, 0.20914088)
# (343, 0.19221878)
# (344, 0.21230376)
# (345, 0.20721765)
# (346, 0.21751904)
# (347, 0.20663586)
# (348, 0.22462657)
# (349, 0.20516407)
# (350, 0.2079855)
# (351, 0.20532003)
# (352, 0.20682085)
# (353, 0.21248971)
# (354, 0.20759375)
# (355, 0.20620517)
# (356, 0.21791959)
# (357, 0.23218675)
# (358, 0.20937638)
# (359, 0.22754352)
# (360, 0.20397964)
# (361, 0.2249908)
# (362, 0.21448484)
# (363, 0.22238818)
# (364, 0.20415261)
# (365, 0.21826096)
# (366, 0.21755488)
# (367, 0.21570997)
# (368, 0.20918612)
# (369, 0.20737445)
# (370, 0.22015409)
# (371, 0.21371208)
# (372, 0.20488547)
# (373, 0.20785592)
# (374, 0.20945048)
# (375, 0.22135578)
# (376, 0.22641814)
# (377, 0.20185271)
# (378, 0.22026496)
# (379, 0.21023047)
# (380, 0.22027932)
# (381, 0.2171638)
# (382, 0.21227606)
# (383, 0.21518075)
# (384, 0.19980049)
# (385, 0.20948564)
# (386, 0.20475511)
# (387, 0.20514365)
# (388, 0.21318312)
# (389, 0.21053357)
# (390, 0.20799255)
# (391, 0.20288165)
# (392, 0.2061553)
# (393, 0.20600033)
# (394, 0.20427461)
# (395, 0.20281427)
# (396, 0.20600486)
# (397, 0.20753777)
# (398, 0.19749053)
# (399, 0.20282331)
# (400, 0.20242634)
# (401, 0.20104204)
# (402, 0.19922093)
# (403, 0.20877962)
# (404, 0.19345562)
# (405, 0.20502801)
# (406, 0.20517097)
# (407, 0.20961599)
# (408, 0.20722365)
# (409, 0.21044722)
# (410, 0.19367133)
# (411, 0.20656577)
# (412, 0.19952841)
# (413, 0.21643205)
# (414, 0.20077749)
# (415, 0.20452002)
# (416, 0.2006949)
# (417, 0.2007102)
# (418, 0.20623846)
# (419, 0.20071581)
# (420, 0.20264868)
# (421, 0.21751142)
# (422, 0.21893619)
# (423, 0.21638186)
# (424, 0.20734106)
# (425, 0.19081159)
# (426, 0.1948741)
# (427, 0.19449292)
# (428, 0.21002732)
# (429, 0.21105967)
# (430, 0.21172106)
# (431, 0.19668785)
# (432, 0.21284544)
# (433, 0.19541328)
# (434, 0.19958204)
# (435, 0.197998)
# (436, 0.20497875)
# (437, 0.20525442)
# (438, 0.19120824)
# (439, 0.19468704)
# (440, 0.21137896)
# (441, 0.20381458)
# (442, 0.20544545)
# (443, 0.20342977)
# (444, 0.19666646)
# (445, 0.19487704)
# (446, 0.20262723)
# (447, 0.2114913)
# (448, 0.19909167)
# (449, 0.21043482)
# (450, 0.19813846)
# (451, 0.2088115)
# (452, 0.21202707)
# (453, 0.19291718)
# (454, 0.1917603)
# (455, 0.20338531)
# (456, 0.19409923)
# (457, 0.20090242)
# (458, 0.19809586)
# (459, 0.20275007)
# (460, 0.21862374)
# (461, 0.20474625)
# (462, 0.19734478)
# (463, 0.20450525)
# (464, 0.2010233)
# (465, 0.20230924)
# (466, 0.20050068)
# (467, 0.20517193)
# (468, 0.20124045)
# (469, 0.20843816)
# (470, 0.20381741)
# (471, 0.21390095)
# (472, 0.20531169)
# (473, 0.18925382)
# (474, 0.19218785)
# (475, 0.20503259)
# (476, 0.20571509)
# (477, 0.1921643)
# (478, 0.19973597)
# (479, 0.208804)
# (480, 0.19823785)
# (481, 0.19716403)
# (482, 0.21116872)
# (483, 0.19654272)
# (484, 0.20134233)
# (485, 0.2039188)
# (486, 0.20644832)
# (487, 0.20736818)
# (488, 0.20292954)
# (489, 0.22512674)
# (490, 0.20371316)
# (491, 0.20916389)
# (492, 0.20499764)
# (493, 0.20526138)
# (494, 0.2104756)
# (495, 0.2005701)
# (496, 0.20485449)
# (497, 0.20144792)
# (498, 0.2024272)
# (499, 0.20045204)
# (500, 0.20296775)
# (501, 0.20054196)
# (502, 0.20937784)
# (503, 0.20444742)
# (504, 0.20027661)
# (505, 0.20345478)
# (506, 0.20120564)
# (507, 0.21305643)
# (508, 0.2021234)
# (509, 0.20663519)
# (510, 0.19738623)
# (511, 0.21433859)
# (512, 0.2014954)
# (513, 0.21168032)
# (514, 0.20313688)
# (515, 0.20283417)
# (516, 0.20738418)
# (517, 0.20112705)
# (518, 0.20198813)
# (519, 0.20342736)
# (520, 0.20296402)
# (521, 0.21125774)
# (522, 0.19293597)
# (523, 0.21461959)
# (524, 0.19998333)
# (525, 0.20676947)
# (526, 0.19850533)
# (527, 0.19990134)
# (528, 0.20513602)
# (529, 0.19368608)
# (530, 0.20680761)
# (531, 0.19745284)
# (532, 0.21139216)
# (533, 0.19918)
# (534, 0.20853055)
# (535, 0.2126566)
# (536, 0.19145505)
# (537, 0.20502274)
# (538, 0.19528328)
# (539, 0.19796066)
# (540, 0.21695438)
# (541, 0.19113863)
# (542, 0.20294344)
# (543, 0.20512398)
# (544, 0.20540927)
# (545, 0.2026447)
# (546, 0.21331468)
# (547, 0.20305486)
# (548, 0.20666742)
# (549, 0.1878155)
# (550, 0.19738069)
# (551, 0.20082965)
# (552, 0.20592366)
# (553, 0.19573902)
# (554, 0.20020579)
# (555, 0.20309167)
# (556, 0.19043244)
# (557, 0.20274858)
# (558, 0.18450783)
# (559, 0.19559789)
# (560, 0.19921854)
# (561, 0.20852347)
# (562, 0.19954967)
# (563, 0.20115995)
# (564, 0.2047493)
# (565, 0.19162369)
# (566, 0.19556573)
# (567, 0.19414666)
# (568, 0.1982771)
# (569, 0.20727324)
# (570, 0.19869502)
# (571, 0.20998637)
# (572, 0.18472372)
# (573, 0.20642541)
# (574, 0.19248153)
# (575, 0.20292428)
# (576, 0.20545316)
# (577, 0.20952487)
# (578, 0.19372265)
# (579, 0.19833423)
# (580, 0.1998122)
# (581, 0.18917535)
# (582, 0.19450012)
# (583, 0.20019384)
# (584, 0.19702926)
# (585, 0.19021392)
# (586, 0.19967084)
# (587, 0.21363501)
# (588, 0.2024871)
# (589, 0.1913917)
# (590, 0.20655034)
# (591, 0.20218654)
# (592, 0.19574395)
# (593, 0.1851799)
# (594, 0.19730096)
# (595, 0.20029393)
# (596, 0.20138064)
# (597, 0.19401316)
# (598, 0.20468593)
# (599, 0.20705669)
# (600, 0.1932941)
# (601, 0.200421)
# (602, 0.20557313)
# (603, 0.21521603)
# (604, 0.22114375)
# (605, 0.20640151)
# (606, 0.19293822)
# (607, 0.2074112)
# (608, 0.2095429)
# (609, 0.20573841)
# (610, 0.21865772)
# (611, 0.203102)
# (612, 0.2113862)
# (613, 0.22196035)
# (614, 0.2147326)
# (615, 0.20558634)
# (616, 0.20951568)
# (617, 0.2005806)
# (618, 0.20564575)
# (619, 0.21070062)
# (620, 0.21447515)
# (621, 0.20470026)
# (622, 0.20330639)
# (623, 0.20973845)
# (624, 0.20212622)
# (625, 0.2168936)
# (626, 0.19641232)
# (627, 0.205758)
# (628, 0.1975479)
# (629, 0.22164755)
# (630, 0.20088111)
# (631, 0.20590536)
# (632, 0.20314837)
# (633, 0.21784262)
# (634, 0.21232562)
# (635, 0.21068227)
# (636, 0.19800091)
# (637, 0.20515989)
# (638, 0.20869732)
# (639, 0.19679545)
# (640, 0.20597863)
# (641, 0.20534034)
# (642, 0.20018835)
# (643, 0.21067083)
# (644, 0.20858257)
# (645, 0.21373203)
# (646, 0.20309801)
# (647, 0.214885)
# (648, 0.20962305)
# (649, 0.19878152)
# (650, 0.19386013)
# (651, 0.21124601)
# (652, 0.2168229)
# (653, 0.21651869)
# (654, 0.19933456)
# (655, 0.20500818)
# (656, 0.18992555)
# (657, 0.19085597)
# (658, 0.20043503)
# (659, 0.21108773)
# (660, 0.19344619)
# (661, 0.19426577)
# (662, 0.20908284)
# (663, 0.20174837)
# (664, 0.19123326)
# (665, 0.2078871)
# (666, 0.20093857)
# (667, 0.19847846)
# (668, 0.19954777)
# (669, 0.19864988)
# (670, 0.19676267)
# (671, 0.19579594)
# (672, 0.19041169)
# (673, 0.20006226)
# (674, 0.19504224)
# (675, 0.19370191)
# (676, 0.20367193)
# (677, 0.18727806)
# (678, 0.20848393)
# (679, 0.21593605)
# (680, 0.2039297)
# (681, 0.21607304)
# (682, 0.2180542)
# (683, 0.21180251)
# (684, 0.20660172)
# (685, 0.19425003)
# (686, 0.21189165)
# (687, 0.2111386)
# (688, 0.20034204)
# (689, 0.20853673)
# (690, 0.19884543)
# (691, 0.20392351)
# (692, 0.20717028)
# (693, 0.1951161)
# (694, 0.20469573)
# (695, 0.18909465)
# (696, 0.20309272)
# (697, 0.20237377)
# (698, 0.21239404)
# (699, 0.20868845)
# (700, 0.20326734)
# (701, 0.20966747)
# (702, 0.20161115)
# (703, 0.20013335)
# (704, 0.20470913)
# (705, 0.20321174)
# (706, 0.19949901)
# (707, 0.18546888)
# (708, 0.20836873)
# (709, 0.214622)
# (710, 0.21924666)
# (711, 0.2079287)
# (712, 0.2045218)
# (713, 0.1957437)
# (714, 0.20384291)
# (715, 0.19747758)
# (716, 0.1854447)
# (717, 0.20551816)
# (718, 0.21829902)
# (719, 0.21701537)
# (720, 0.19746374)
# (721, 0.19544251)
# (722, 0.22771592)
# (723, 0.20531459)
# (724, 0.20247327)
# (725, 0.20251547)
# (726, 0.2135262)
# (727, 0.2004536)
# (728, 0.19614851)
# (729, 0.20913525)
# (730, 0.18622911)
# (731, 0.19946134)
# (732, 0.20493971)
# (733, 0.18711376)
# (734, 0.21475184)
# (735, 0.20667951)
# (736, 0.21064167)
# (737, 0.19643514)
# (738, 0.22577663)
# (739, 0.19922394)
# (740, 0.20111266)
# (741, 0.2069728)
# (742, 0.20393753)
# (743, 0.20360485)
# (744, 0.2066723)
# (745, 0.1982088)
# (746, 0.20448951)
# (747, 0.22243027)
# (748, 0.19675897)
# (749, 0.21013398)
# (750, 0.19636987)
# (751, 0.22285883)
# (752, 0.20256375)
# (753, 0.21492217)
# (754, 0.19664882)
# (755, 0.20338999)
# (756, 0.19321053)
# (757, 0.18912084)
# (758, 0.20811386)
# (759, 0.20543967)
# (760, 0.21738823)
# (761, 0.207961)
# (762, 0.19647957)
# (763, 0.19624335)
# (764, 0.20990744)
# (765, 0.21052198)
# (766, 0.2069354)
# (767, 0.18911031)
# (768, 0.20609736)
# (769, 0.21641679)
# (770, 0.20494469)
# (771, 0.21522379)
# (772, 0.20165573)
# (773, 0.21257317)
# (774, 0.18953061)
# (775, 0.20819135)
# (776, 0.19489749)
# (777, 0.19886065)
# (778, 0.2050005)
# (779, 0.19585599)
# (780, 0.19863415)
# (781, 0.19847065)
# (782, 0.20192292)
# (783, 0.20007797)
# (784, 0.20195782)
# (785, 0.18861699)
# (786, 0.20028389)
# (787, 0.20709376)
# (788, 0.1927212)
# (789, 0.20235609)
# (790, 0.20948736)
# (791, 0.19730616)
# (792, 0.20063452)
# (793, 0.20333986)
# (794, 0.18594198)
# (795, 0.19638948)
# (796, 0.20388713)
# (797, 0.20469396)
# (798, 0.19956234)
# (799, 0.20356627)
# (800, 0.18745911)
# (801, 0.20770684)
# (802, 0.19731419)
# (803, 0.20818086)
# (804, 0.19619606)
# (805, 0.196316)
# (806, 0.20166612)
# (807, 0.19751714)
# (808, 0.19720852)
# (809, 0.19146101)
# (810, 0.19513658)
# (811, 0.20582779)
# (812, 0.21460377)
# (813, 0.21501355)
# (814, 0.19661526)
# (815, 0.18943565)
# (816, 0.19227989)
# (817, 0.18942851)
# (818, 0.20727539)
# (819, 0.2065682)
# (820, 0.21283315)
# (821, 0.18701485)
# (822, 0.20164429)
# (823, 0.18595079)
# (824, 0.19597395)
# (825, 0.19534235)
# (826, 0.2023077)
# (827, 0.19403203)
# (828, 0.1868964)
# (829, 0.19004914)
# (830, 0.20258482)
# (831, 0.19203062)
# (832, 0.20727316)
# (833, 0.19649033)
# (834, 0.18846653)
# (835, 0.18995817)
# (836, 0.18681262)
# (837, 0.20182204)
# (838, 0.18938385)
# (839, 0.20426343)
# (840, 0.19250138)
# (841, 0.20240311)
# (842, 0.20619312)
# (843, 0.18013656)
# (844, 0.18430853)
# (845, 0.19688708)
# (846, 0.18578713)
# (847, 0.19225694)
# (848, 0.18963023)
# (849, 0.19595034)
# (850, 0.21072002)
# (851, 0.19993265)
# (852, 0.19339673)
# (853, 0.19943641)
# (854, 0.18822828)
# (855, 0.19229554)
# (856, 0.198479)
# (857, 0.20325582)
# (858, 0.19403663)
# (859, 0.19653763)
# (860, 0.19375975)
# (861, 0.21475792)
# (862, 0.20374809)
# (863, 0.1844654)
# (864, 0.18700321)
# (865, 0.19494604)
# (866, 0.20277964)
# (867, 0.1884408)
# (868, 0.197976)
# (869, 0.19496639)
# (870, 0.19179711)
# (871, 0.19232443)
# (872, 0.20069113)
# (873, 0.18877752)
# (874, 0.2020107)
# (875, 0.2022554)
# (876, 0.19992734)
# (877, 0.20206313)
# (878, 0.19403607)
# (879, 0.22130601)
# (880, 0.19399917)
# (881, 0.20449744)
# (882, 0.19837204)
# (883, 0.20911622)
# (884, 0.20479846)
# (885, 0.1954295)
# (886, 0.19795164)
# (887, 0.19405755)
# (888, 0.19420423)
# (889, 0.19418009)
# (890, 0.19473703)
# (891, 0.1979859)
# (892, 0.20425971)
# (893, 0.20515369)
# (894, 0.1950903)
# (895, 0.20028046)
# (896, 0.20037614)
# (897, 0.20833293)
# (898, 0.19471155)
# (899, 0.19462034)
# (900, 0.19226001)
# (901, 0.2068337)
# (902, 0.19991533)
# (903, 0.21326657)
# (904, 0.19770789)
# (905, 0.19676453)
# (906, 0.2089043)
# (907, 0.19149843)
# (908, 0.19249783)
# (909, 0.19900587)
# (910, 0.20061584)
# (911, 0.20414749)
# (912, 0.18412183)
# (913, 0.21133785)
# (914, 0.1929738)
# (915, 0.2012256)
# (916, 0.19339654)
# (917, 0.19313712)
# (918, 0.20467336)
# (919, 0.18685335)
# (920, 0.20294224)
# (921, 0.19525242)
# (922, 0.20400195)
# (923, 0.19608533)
# (924, 0.20567608)
# (925, 0.20395182)
# (926, 0.18175264)
# (927, 0.19971463)
# (928, 0.18673706)
# (929, 0.19607012)
# (930, 0.2138237)
# (931, 0.18573347)
# (932, 0.19673334)
# (933, 0.19770801)
# (934, 0.19786806)
# (935, 0.19820403)
# (936, 0.20648232)
# (937, 0.19503608)
# (938, 0.20495258)
# (939, 0.18116724)
# (940, 0.18890204)
# (941, 0.19697547)
# (942, 0.19922607)
# (943, 0.18924595)
# (944, 0.19654264)
# (945, 0.1913753)
# (946, 0.19204617)
# (947, 0.20299783)
# (948, 0.17381044)
# (949, 0.18967052)
# (950, 0.18984221)
# (951, 0.20862685)
# (952, 0.19625294)
# (953, 0.20035529)
# (954, 0.19453736)
# (955, 0.18740253)
# (956, 0.19391207)
# (957, 0.19327864)
# (958, 0.19436666)
# (959, 0.19814031)
# (960, 0.19310509)
# (961, 0.21111155)
# (962, 0.18180151)
# (963, 0.20219903)
# (964, 0.19906633)
# (965, 0.19474986)
# (966, 0.19516332)
# (967, 0.2018044)
# (968, 0.19665678)
# (969, 0.19426195)
# (970, 0.19484392)
# (971, 0.1866954)
# (972, 0.18949144)
# (973, 0.19706176)
# (974, 0.19207326)
# (975, 0.18096018)
# (976, 0.19489662)
# (977, 0.20795785)
# (978, 0.2024701)
# (979, 0.18975763)
# (980, 0.20031253)
# (981, 0.19478202)
# (982, 0.19192265)
# (983, 0.17731999)
# (984, 0.18601951)
# (985, 0.19588692)
# (986, 0.2011174)
# (987, 0.19122787)
# (988, 0.19288632)
# (989, 0.19871226)
# (990, 0.17611252)
# (991, 0.19938424)
# (992, 0.20448692)
# (993, 0.20394011)
# (994, 0.2087684)
# (995, 0.20091525)
# (996, 0.18274164)
# (997, 0.19533978)
# (998, 0.20750828)
# (999, 0.19666593)
# (1000, 0.2011935)
# (1001, 0.1985089)
# (1002, 0.20121638)
# (1003, 0.21654606)
# (1004, 0.21209268)
# (1005, 0.19398199)
# (1006, 0.19981581)
# (1007, 0.19414493)
# (1008, 0.19701238)
# (1009, 0.20745412)
# (1010, 0.20546766)
# (1011, 0.20569988)
# (1012, 0.20433941)
# (1013, 0.19958465)
# (1014, 0.19530654)
# (1015, 0.20916927)
# (1016, 0.1988389)
# (1017, 0.19876964)
# (1018, 0.19251953)
# (1019, 0.21142855)
# (1020, 0.20170891)
# (1021, 0.19868289)
# (1022, 0.20049703)
# (1023, 0.2169615)
# (1024, 0.20804815)
# (1025, 0.20725465)
# (1026, 0.19243978)
# (1027, 0.19445448)
# (1028, 0.20560133)
# (1029, 0.19413283)
# (1030, 0.19965789)
# (1031, 0.19704702)
# (1032, 0.1934772)
# (1033, 0.209231)
# (1034, 0.19616249)
# (1035, 0.20810504)
# (1036, 0.20267808)
# (1037, 0.20813711)
# (1038, 0.19912294)
# (1039, 0.18688975)
# (1040, 0.19103965)
# (1041, 0.20784464)
# (1042, 0.2183876)
# (1043, 0.21017049)
# (1044, 0.19423167)
# (1045, 0.20188613)
# (1046, 0.18188505)
# (1400, 0.19813053)
# (1401, 0.19757782)
# (1402, 0.19686504)
# (1403, 0.20006776)
# (1404, 0.18623498)
# (1405, 0.20872521)
# (1406, 0.19542329)
# (1407, 0.1954337)
# (1408, 0.18312272)
# (1409, 0.20423365)
# (1410, 0.19757839)
# (1411, 0.20577107)
# (1412, 0.19471048)
# (1413, 0.20955296)
# (1414, 0.20261335)
# (1415, 0.21061726)
# (1416, 0.18594447)
# (1417, 0.19128618)
# (1418, 0.1989616)
# (1419, 0.2002007)
# (1420, 0.19962017)
# (1421, 0.20226574)
# (1422, 0.19834559)
# (1423, 0.20836912)
# (1424, 0.20192914)
# (1425, 0.20393093)
# (1426, 0.1997824)
# (1427, 0.2014819)
# (1428, 0.20047359)
# (1429, 0.19107746)
# (1430, 0.19046804)
# (1431, 0.21296887)
# (1432, 0.22209263)
# (1433, 0.21393497)
# (1434, 0.1958669)
# (1435, 0.20798974)
# (1436, 0.18304348)
# (1437, 0.19396158)
# (1438, 0.19698349)
# (1439, 0.20204556)
# (1440, 0.18905918)
# (1441, 0.19131164)
# (1442, 0.2024703)
# (1443, 0.19650792)
# (1444, 0.1901413)
# (1445, 0.20904568)
# (1446, 0.20353416)
# (1447, 0.19650558)
# (1448, 0.20235835)
# (1449, 0.20236662)
# (1450, 0.1963812)
# (1451, 0.19350015)
# (1452, 0.1852793)
# (1453, 0.19592878)
# (1454, 0.19398804)
# (1455, 0.19063635)
# (1456, 0.1985216)
# (1457, 0.18533567)
# (1458, 0.1995586)
# (1459, 0.21066307)
# (1460, 0.20096238)
# (1461, 0.19622467)
# (1462, 0.21179228)
# (1463, 0.20711906)
# (1464, 0.20661245)
# (1465, 0.18848883)
# (1466, 0.20666204)
# (1467, 0.20645793)
# (1468, 0.19442795)
# (1469, 0.21084212)
# (1470, 0.20388117)
# (1471, 0.19987689)
# (1472, 0.20778604)
# (1473, 0.18835329)
# (1474, 0.19341996)
# (1475, 0.17477416)
# (1476, 0.19949631)
# (1477, 0.19598043)
# (1478, 0.20465028)
# (1479, 0.20568247)
# (1480, 0.20399193)
# (1481, 0.20676088)
# (1482, 0.19202007)
# (1483, 0.2047036)
# (1484, 0.19554217)
# (1485, 0.1957936)
# (1486, 0.20409107)
# (1487, 0.18472375)
# (1488, 0.20670162)
# (1489, 0.20242392)
# (1490, 0.21925414)
# (1491, 0.21850196)
# (1492, 0.21132211)
# (1493, 0.19848333)
# (1494, 0.19267413)
# (1495, 0.19642977)
# (1496, 0.18770249)
# (1497, 0.19199948)
# (1498, 0.20642363)
# (1499, 0.2081672)
# (1500, 0.19307734)
# (1501, 0.18469201)
# (1502, 0.23485298)
# (1503, 0.19766103)
# (1504, 0.19863962)
# (1505, 0.1897449)
# (1506, 0.18894601)
# (1507, 0.2009347)
# (1508, 0.19361067)
# (1509, 0.21439707)
# (1510, 0.1894779)
# (1511, 0.19983009)
# (1512, 0.20149589)
# (1513, 0.18827586)
# (1514, 0.20470838)
# (1515, 0.18854617)
# (1516, 0.18923135)
# (1752, 0.18558462)
# (1753, 0.19266458)
# (1754, 0.1907802)
# (1755, 0.17801379)
# (1756, 0.18979676)
# (1757, 0.21311486)
# (1758, 0.19950761)
# (1759, 0.18646407)
# (1760, 0.19307995)
# (1761, 0.18781936)
# (1762, 0.19020392)
# (1763, 0.17076813)
# (1764, 0.18323855)
# (1765, 0.18958764)
# (1766, 0.1939684)
# (1767, 0.18601492)
# (1768, 0.18671)
# (1769, 0.1909874)
# (1770, 0.17000319)
# (1771, 0.19483827)
# (1772, 0.19630234)
# (1773, 0.19115055)
# (1774, 0.20812266)
# (1775, 0.19408256)
# (1776, 0.18393104)
# (1777, 0.19880454)
# (1778, 0.19834022)
# (1779, 0.1917902)
# (1780, 0.19244777)
# (1781, 0.1931415)
# (1782, 0.19181874)
# (1783, 0.21193571)
# (1784, 0.20808648)
# (1785, 0.18276417)
# (1786, 0.19340312)
# (1787, 0.19753827)
# (1788, 0.2026604)
# (1789, 0.21167564)
# (1790, 0.19896202)
# (1791, 0.20037459)
# (1792, 0.1877983)
# (1793, 0.1977099)
# (1794, 0.19786574)
# (1795, 0.211342)
# (1796, 0.18959354)
# (1797, 0.19207843)
# (1798, 0.17933628)
# (1799, 0.2082663)
# (1800, 0.18925075)
# (1801, 0.19355848)
# (1802, 0.20157838)
# (1803, 0.20471454)
# (1804, 0.19717127)
# (1805, 0.19662258)
# (1806, 0.18929397)
# (1807, 0.18683527)
# (1808, 0.19194621)
# (1809, 0.1964505)
# (1810, 0.19772267)
# (1811, 0.19077341)
# (1812, 0.1888483)
# (1813, 0.19925399)
# (1814, 0.20379138)
# (1815, 0.2001678)
# (1816, 0.19719017)
# (1817, 0.19893785)
# (1818, 0.21221514)
# (1819, 0.19287993)
# (1820, 0.18888092)
# (1821, 0.21582823)
# (1822, 0.22429848)
# (1823, 0.20774618)
# (1824, 0.19409676)
# (1825, 0.20090535)
# (1826, 0.18597431)
# (1827, 0.19494942)
# (1828, 0.19988094)
# (1829, 0.19480143)
# (1830, 0.18753618)
# (1831, 0.18664692)
# (1832, 0.19708596)
# (1833, 0.19847369)
# (1834, 0.18109024)
# (1835, 0.20183985)
# (1836, 0.19649278)
# (1837, 0.18114153)
# (1838, 0.20495406)
# (1839, 0.20314495)
# (1840, 0.1897564)
# (1841, 0.19352777)
# (1842, 0.17946804)
# (1843, 0.19416633)
# (1844, 0.1844197)
# (1845, 0.18913056)
# (1846, 0.20129672)
# (1847, 0.19070251)
# (1848, 0.20261657)
# (1849, 0.20488267)
# (1850, 0.19403699)
# (1851, 0.2047557)
# (1852, 0.18925576)
# (1853, 0.19693892)
# (1854, 0.2116224)
# (1855, 0.19713795)
# (1856, 0.21172194)
# (1857, 0.20768456)
# (1858, 0.2016731)
# (1859, 0.20638037)
# (1860, 0.19285308)
# (1861, 0.1985112)
# (1862, 0.19802696)
# (1863, 0.18018162)
# (1864, 0.19399098)
# (1865, 0.18164968)
# (1866, 0.19465458)
# (1867, 0.1835213)
# (1868, 0.19988269)
# (1869, 0.1983743)
# (1870, 0.20001073)
# (1871, 0.20547752)
# (1872, 0.1924498)
# (1873, 0.1916358)
# (1874, 0.1932503)
# (1875, 0.19724724)
# (1876, 0.2088503)
# (1877, 0.19351915)
# (1878, 0.199994)
# (1879, 0.2088037)
# (1880, 0.23422788)
# (1881, 0.20237637)
# (1882, 0.21531276)
# (1883, 0.19564734)
# (1884, 0.19677065)
# (1885, 0.18304263)
# (1886, 0.18989079)
# (1887, 0.21516128)
# (1888, 0.2116888)
# (1889, 0.20971584)
# (1890, 0.18744901)
# (1891, 0.18416043)
# (1892, 0.22790504)
# (1893, 0.21688357)
# (1894, 0.19701381)
# (1895, 0.18644397)
# (1896, 0.18927072)
# (1897, 0.20890091)
# (1898, 0.19877522)
# (1899, 0.19586636)
# (1900, 0.18645553)
# (1901, 0.20843315)
# (1902, 0.19637512)
# (1903, 0.18414198)
# (1904, 0.19111443)
# (1905, 0.18997005)
# (1906, 0.20624022)
# (1907, 0.18539439)
# (1908, 0.19798274)
# (1909, 0.18938695)
# (1910, 0.20258532)
# (1911, 0.18437755)
# (1912, 0.19831741)
# (1913, 0.20680857)
# (1914, 0.19252157)
# (1915, 0.18527757)
# (1916, 0.19560285)
# (1917, 0.21238194)
# (1918, 0.18071277)
# (1919, 0.19600955)
# (1920, 0.18837981)
# (1921, 0.21142717)
# (1922, 0.21605702)
# (1923, 0.20587125)
# (1924, 0.1913911)
# (1925, 0.19481924)
# (1926, 0.1810218)
# (1927, 0.18621603)
# (1928, 0.19874898)
# (1929, 0.20701312)
# (1930, 0.200416)
# (1931, 0.21308222)
# (1932, 0.19689336)
# (1933, 0.19931036)
# (1934, 0.21654287)
# (1935, 0.21562076)
# (1936, 0.20028977)
# (1937, 0.18443699)
# (1938, 0.20774512)
# (1939, 0.19894102)
# (1940, 0.19223666)
# (1941, 0.190486)
# (1942, 0.19167733)
# (1943, 0.19877994)
# (1944, 0.18434326)
# (1945, 0.20135902)
# (1946, 0.19371043)
# (1947, 0.19312383)
# (1948, 0.19823329)
# (1949, 0.19221447)
# (1950, 0.20059942)
# (1951, 0.1862757)
# (1952, 0.201646)
# (1953, 0.19584003)
# (1954, 0.18781437)
# (1955, 0.1828286)
# (1956, 0.19662718)
# (1957, 0.19759542)
# (1958, 0.17314617)
# (1959, 0.20127086)
# (1960, 0.19793189)
# (1961, 0.18492281)
# (1962, 0.18207133)
# (1963, 0.1984162)
# (1964, 0.18000741)
# (1965, 0.19027092)
# (1966, 0.18882929)
# (1967, 0.19989501)
# (1968, 0.17793952)
# (1969, 0.19459057)
# (1970, 0.17782989)
# (1971, 0.19992211)
# (1972, 0.17648105)
# (1973, 0.20142384)
# (1974, 0.18858366)
# (1975, 0.18234539)
# (1976, 0.18973666)
# (1977, 0.18350388)
# (1978, 0.17886828)
# (1979, 0.18040258)
# (1980, 0.1881961)
# (1981, 0.19497824)
# (1982, 0.20646326)
# (1983, 0.20088248)
# (1984, 0.18505786)
# (1985, 0.17876355)
# (1986, 0.18415006)
# (1987, 0.1873387)
# (1988, 0.19518194)
# (1989, 0.19519259)
# (1990, 0.200241)
# (1991, 0.17497905)
# (1992, 0.18463936)
# (1993, 0.17360708)
# (1994, 0.1814538)
# (1995, 0.1879224)
# (1996, 0.19378738)
# (1997, 0.18611002)
# (1998, 0.17743821)
# (1999, 0.17671092)
# (2000, 0.19763978)
# (2001, 0.17848471)
# (2002, 0.19557476)
# (2003, 0.18536775)
# (2004, 0.1884779)
# (2005, 0.18275528)
# (2006, 0.17853841)
# (2007, 0.18590145)
# (2008, 0.17550783)
# (2009, 0.1935219)
# (2010, 0.18880844)
# (2011, 0.19036236)
# (2012, 0.19924958)
# (2013, 0.16616194)
# (2014, 0.18402867)
# (2015, 0.18162166)
# (2016, 0.1762152)
# (2017, 0.17308135)
# (2018, 0.18278734)
# (2019, 0.19330084)
# (2020, 0.20737195)
# (2021, 0.19001906)
# (2022, 0.18718675)
# (2023, 0.19149502)
# (2024, 0.18046868)
# (2025, 0.18039757)
# (2026, 0.19373372)
# (2027, 0.1979213)
# (2028, 0.19015683)
# (2029, 0.18706886)
# (2030, 0.18494609)
# (2031, 0.20518842)
# (2032, 0.18893433)
# (2033, 0.1855189)
# (2034, 0.18425427)
# (2035, 0.18665166)
# (2036, 0.19862641)
# (2037, 0.17985085)
# (2038, 0.19093323)
# (2039, 0.18127792)
# (2040, 0.18492703)
# (2041, 0.18195538)
# (2042, 0.18667169)
# (2043, 0.18726242)
# (2044, 0.19194654)
# (2045, 0.19343932)
# (2046, 0.18444188)
# (2047, 0.18874402)
# (2048, 0.19105907)
# (2049, 0.21141468)
# (2050, 0.18863042)
# (2051, 0.205408)
# (2052, 0.18911918)
# (2053, 0.19690113)
# (2054, 0.20594049)
# (2055, 0.18490186)
# (2056, 0.18358488)
# (2057, 0.1879415)
# (2058, 0.1906104)
# (2059, 0.19427776)
# (2060, 0.19570266)
# (2061, 0.20260668)
# (2062, 0.19765225)
# (2063, 0.1973441)
# (2064, 0.19650644)
# (2065, 0.19516511)
# (2066, 0.20092526)
# (2067, 0.20253013)
# (2068, 0.19775084)
# (2069, 0.18411796)
# (2070, 0.18817694)
# (2071, 0.20122103)
# (2072, 0.20036368)
# (2073, 0.20175295)
# (2074, 0.19063786)
# (2075, 0.20019953)
# (2076, 0.20049182)
# (2077, 0.19129822)
# (2078, 0.18688181)
# (2079, 0.19331095)
# (2080, 0.18778645)
# (2081, 0.19625157)
# (2082, 0.17165981)
# (2083, 0.20144501)
# (2084, 0.18877952)
# (2085, 0.19636896)
# (2086, 0.19120564)
# (2087, 0.18969843)
# (2088, 0.19955067)
# (2089, 0.17805326)
# (2090, 0.18943754)
# (2091, 0.18690257)
# (2092, 0.19917206)
# (2093, 0.18127452)
# (2094, 0.1998906)
# (2095, 0.19228496)
# (2096, 0.17749618)
# (2097, 0.20220971)
# (2098, 0.1857882)
# (2099, 0.20090185)
# (2100, 0.210359)
# (2101, 0.18323706)
# (2102, 0.196088)
# (2103, 0.19110805)
# (2104, 0.19982556)
# (2105, 0.19840167)
# (2106, 0.19920255)
# (2107, 0.19733863)
# (2108, 0.20921944)
# (2109, 0.17868829)
# (2110, 0.17647903)
# (2111, 0.19814438)
# (2112, 0.18817215)
# (2113, 0.1771175)
# (2114, 0.1856605)
# (2115, 0.18609658)
# (2116, 0.19665162)
# (2117, 0.19194297)
# (2118, 0.18040504)
# (2119, 0.18508402)
# (2120, 0.18049544)
# (2121, 0.1994346)
# (2122, 0.19598164)
# (2123, 0.19355586)
# (2124, 0.18832181)
# (2125, 0.18897417)
# (2126, 0.18426974)
# (2127, 0.17396764)
# (2128, 0.20091446)
# (2129, 0.18821163)
# (2130, 0.19004326)
# (2131, 0.2033972)
# (2132, 0.17533243)
# (2133, 0.2054712)
# (2134, 0.20554733)
# (2135, 0.19554155)
# (2136, 0.19817887)
# (2137, 0.19580373)
# (2138, 0.19770353)
# (2139, 0.20822763)
# (2140, 0.19942598)
# (2141, 0.1955003)
# (2142, 0.19938561)
# (2143, 0.194734)
# (2144, 0.20674787)
# (2145, 0.18241353)
# (2146, 0.20983167)
# (2147, 0.20617054)
# (2148, 0.2019155)
# (2149, 0.18864335)
# (2150, 0.19300789)
# (2151, 0.19078465)
# (2152, 0.19006287)
# (2153, 0.16693102)
# (2154, 0.17318502)
# (2155, 0.19777825)
# (2156, 0.19427216)
# (2157, 0.17570798)
# (2158, 0.18296587)
# (2159, 0.18944207)
# (2160, 0.184359)
# (2161, 0.2000302)
# (2162, 0.18639801)
# (2163, 0.21171151)
# (2164, 0.19715522)
# (2165, 0.18999939)
# (2166, 0.1738072)
# (2167, 0.20326595)
# (2168, 0.2014728)
# (2169, 0.1840553)
# (2170, 0.20135646)
# (2171, 0.20396255)
# (2172, 0.19875555)
# (2173, 0.2142004)
# (2174, 0.21466477)
# (2175, 0.19657013)
# (2176, 0.19852494)
# (2177, 0.20013297)
# (2178, 0.19942953)
# (2179, 0.20382069)
# (2180, 0.20700851)
# (2181, 0.21209891)
# (2182, 0.18663697)
# (2183, 0.20355292)
# (2184, 0.19608459)
# (2185, 0.20749569)
# (2186, 0.19377649)
# (2187, 0.19352233)
# (2188, 0.18045972)
# (2189, 0.20050684)
# (2190, 0.18487239)
# (2191, 0.19399193)
# (2192, 0.20134912)
# (2193, 0.22195064)
# (2194, 0.19576558)
# (2195, 0.2248969)
# (2196, 0.19346826)
# (2197, 0.1858874)
# (2198, 0.18982302)
# (2199, 0.2051013)
# (2200, 0.20067756)
# (2201, 0.19016026)
# (2202, 0.2055409)
# (2203, 0.20577185)
# (2204, 0.19848576)
# (2205, 0.20685367)
# (2206, 0.19654141)
# (2207, 0.19721799)
# (2208, 0.20664349)
# (2209, 0.19322242)
# (2210, 0.20437436)
# (2211, 0.22211428)
# (2212, 0.21383624)
# (2213, 0.2027636)
# (2214, 0.19698861)
# (2215, 0.20657228)
# (2216, 0.18333934)
# (2217, 0.17585348)
# (2218, 0.18830918)
# (2219, 0.20346561)
# (2220, 0.1829845)
# (2221, 0.18397677)
# (2222, 0.1891431)
# (2223, 0.19704795)
# (2224, 0.17899875)
# (2225, 0.19543909)
# (2226, 0.2104559)
# (2227, 0.18571207)
# (2228, 0.20328708)
# (2229, 0.20130067)
# (2230, 0.18668)
# (2231, 0.20036231)
# (2232, 0.18981488)
# (2233, 0.20539796)
# (2234, 0.19095206)
# (2235, 0.19370008)
# (2236, 0.20813675)
# (2237, 0.18620612)
# (2238, 0.18522207)
# (2239, 0.1998473)
# (2240, 0.19683821)
# (2241, 0.20284517)
# (2242, 0.20064612)
# (2243, 0.20109944)
# (2244, 0.20093487)
# (2245, 0.18045337)
# (2246, 0.18678467)
# (2247, 0.20481233)
# (2248, 0.19143443)
# (2249, 0.19652663)
# (2250, 0.19133376)
# (2251, 0.19184344)
# (2252, 0.19476089)
# (2253, 0.18220824)
# (2254, 0.18128571)
# (2255, 0.16599016)
# (2256, 0.19446205)
# (2257, 0.19185981)
# (2258, 0.18641897)
# (2259, 0.21998356)
# (2260, 0.19002831)
# (2261, 0.20276098)
# (2262, 0.18990615)
# (2263, 0.19976386)
# (2264, 0.19866668)
# (2265, 0.19034268)
# (2266, 0.20826362)
# (2267, 0.18378268)
# (2268, 0.20839353)
# (2269, 0.20449054)
# (2270, 0.22272103)
# (2271, 0.2102154)
# (2272, 0.20550768)
# (2273, 0.1896721)
# (2274, 0.19200024)
# (2275, 0.18792816)
# (2276, 0.20540844)
# (2277, 0.20808382)
# (2278, 0.2194378)
# (2279, 0.20023456)
# (2280, 0.17988585)
# (2281, 0.18082741)
# (2282, 0.21135612)
# (2283, 0.22928758)
# (2284, 0.20318937)
# (2285, 0.20168939)
# (2286, 0.28083536)
# (2287, 0.20868586)
# (2288, 0.28456566)
# (2289, 0.3442746)
# (2290, 0.3172669)
# (2291, 0.49468517)
# (2292, 0.3954578)
# (2293, 0.36682656)
# (2294, 1.1896926)
# (2295, 0.7998105)
# (2296, 2.8858533)
# (2297, 1.3318714)
# (2298, 2.4566967)
# (2299, 3.6884038)
# (2300, 3.6633499)
# (2301, 4.0422034)
# (2302, 5.2664933)
# (2303, 6.8017387)
# (2304, 8.608369)
# (2305, 4.6578693)
# (2306, 5.1315885)
# (2307, 3.7165852)
# (2308, 6.9737396)
# (2309, 6.8605256)
# (2310, 6.9018784)
# (2311, 4.026407)
# (2312, 5.194885)
# (2313, 5.642205)
# (2314, 7.3913817)
# (2315, 8.821604)
# (2316, 7.684461)
# (2317, 7.7131753)
# (2318, 6.014849)
# (2319, 3.4561565)
# (2320, 3.3652902)
# (2321, 2.2104256)
# (2322, 1.2047719)
# (2323, 1.1397775)
# (2324, 0.62656945)
# (2325, 0.94477224)
# (2326, 0.63760155)
# (2327, 0.64800555)
# (2328, 0.5492673)
# (2329, 0.5594587)
# (2330, 0.5348729)
# (2331, 0.47094136)
# (2332, 0.45624414)
# (2333, 0.5218272)
# (2334, 0.36604008)
# (2335, 0.32836866)
# (2336, 0.2940801)
# (2337, 0.28631243)
# (2338, 0.29352543)
# (2339, 0.3464099)
