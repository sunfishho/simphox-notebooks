# %%
# %load_ext autoreload
# %autoreload 2

# %%
from PIL import Image, ImageFilter
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F

USE_GPU = True
dtype = torch.float32 # We will be using float throughout this tutorial.

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss.
# print_every = 100
print('using device:', device)
# Out:
# using device: cpu

# %%
def flatten(x):
    N = x.shape[0]
    return x.view(N, -1)

class Flatten(nn.Module):
    def forward(self, x):
        return flatten(x)

# %%
gray_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),  # Normalize the data
    transforms.Grayscale(1)
])

gray_trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=gray_transform)
gray_trainloader = torch.utils.data.DataLoader(gray_trainset, batch_size=64,
                                          shuffle=True)

gray_testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=gray_transform)
gray_testloader = torch.utils.data.DataLoader(gray_testset, batch_size=64,
                                         shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def gray_check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on train set')
    else:
        print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

test_accuracies = []
train_accuracies = []

def gray_train(model, optimizer, epochs=10):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(gray_trainloader):
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

        print(f'Epoch {e}, loss = {loss.item()}')
        test_accuracies.append(gray_check_accuracy(gray_testloader, model))
        train_accuracies.append(gray_check_accuracy(gray_trainloader, model))
        print()

# %%
learning_rate = 0.001

fully_connected_model = nn.Sequential(
    Flatten(),
    nn.Linear(1024, 1024),
    nn.ReLU(),
    nn.Linear(1024, 1024),
    nn.ReLU(),
    nn.Linear(1024, 10)
)

optimizer = optim.SGD(fully_connected_model.parameters(), lr=learning_rate, momentum=0.9, nesterov=True)
gray_train(fully_connected_model, optimizer, epochs = 50)
# Out:
# Epoch 0, loss = 2.1699349880218506
# Checking accuracy on test set
# Got 2265 / 10000 correct (22.65)
# Checking accuracy on train set
# Got 11152 / 50000 correct (22.30)
#
# Epoch 1, loss = 2.120011329650879
# Checking accuracy on test set
# Got 2673 / 10000 correct (26.73)
# Checking accuracy on train set
# Got 13268 / 50000 correct (26.54)
#
# Epoch 2, loss = 2.016875982284546
# Checking accuracy on test set
# Got 3042 / 10000 correct (30.42)
# Checking accuracy on train set
# Got 15127 / 50000 correct (30.25)
#
# Epoch 3, loss = 2.010275363922119
# Checking accuracy on test set
# Got 3340 / 10000 correct (33.40)
# Checking accuracy on train set
# Got 16641 / 50000 correct (33.28)
#
# Epoch 4, loss = 1.6363526582717896
# Checking accuracy on test set
# Got 3568 / 10000 correct (35.68)
# Checking accuracy on train set
# Got 17841 / 50000 correct (35.68)
#
# Epoch 5, loss = 1.8993582725524902
# Checking accuracy on test set
# Got 3696 / 10000 correct (36.96)
# Checking accuracy on train set
# Got 18856 / 50000 correct (37.71)
#
# Epoch 6, loss = 1.7633613348007202
# Checking accuracy on test set
# Got 3898 / 10000 correct (38.98)
# Checking accuracy on train set
# Got 19792 / 50000 correct (39.58)
#
# Epoch 7, loss = 1.861991286277771
# Checking accuracy on test set
# Got 4012 / 10000 correct (40.12)
# Checking accuracy on train set
# Got 20791 / 50000 correct (41.58)
#
# Epoch 8, loss = 1.69179105758667
# Checking accuracy on test set
# Got 4074 / 10000 correct (40.74)
# Checking accuracy on train set
# Got 21631 / 50000 correct (43.26)
#
# Epoch 9, loss = 1.4686143398284912
# Checking accuracy on test set
# Got 4160 / 10000 correct (41.60)
# Checking accuracy on train set
# Got 22388 / 50000 correct (44.78)
#
# Epoch 10, loss = 1.8681849241256714
# Checking accuracy on test set
# Got 4223 / 10000 correct (42.23)
# Checking accuracy on train set
# Got 23045 / 50000 correct (46.09)
#
# Epoch 11, loss = 1.2166026830673218
# Checking accuracy on test set
# Got 4306 / 10000 correct (43.06)
# Checking accuracy on train set
# Got 23788 / 50000 correct (47.58)
#
# Epoch 12, loss = 1.3795067071914673
# Checking accuracy on test set
# Got 4327 / 10000 correct (43.27)
# Checking accuracy on train set
# Got 24582 / 50000 correct (49.16)
#
# Epoch 13, loss = 1.8446438312530518
# Checking accuracy on test set
# Got 4373 / 10000 correct (43.73)
# Checking accuracy on train set
# Got 25024 / 50000 correct (50.05)
#
# Epoch 14, loss = 1.3703341484069824
# Checking accuracy on test set
# Got 4353 / 10000 correct (43.53)
# Checking accuracy on train set
# Got 25203 / 50000 correct (50.41)
#
# Epoch 15, loss = 1.131542444229126
# Checking accuracy on test set
# Got 4523 / 10000 correct (45.23)
# Checking accuracy on train set
# Got 26376 / 50000 correct (52.75)
#
# Epoch 16, loss = 1.0869152545928955
# Checking accuracy on test set
# Got 4415 / 10000 correct (44.15)
# Checking accuracy on train set
# Got 26661 / 50000 correct (53.32)
#
# Epoch 17, loss = 1.742085576057434
# Checking accuracy on test set
# Got 4479 / 10000 correct (44.79)
# Checking accuracy on train set
# Got 26982 / 50000 correct (53.96)
#
# Epoch 18, loss = 0.7856238484382629
# Checking accuracy on test set
# Got 4517 / 10000 correct (45.17)
# Checking accuracy on train set
# Got 28489 / 50000 correct (56.98)
#
# Epoch 19, loss = 1.454362392425537
# Checking accuracy on test set
# Got 4455 / 10000 correct (44.55)
# Checking accuracy on train set
# Got 28712 / 50000 correct (57.42)
#
# Epoch 20, loss = 1.1707345247268677
# Checking accuracy on test set
# Got 4555 / 10000 correct (45.55)
# Checking accuracy on train set
# Got 29457 / 50000 correct (58.91)
#
# Epoch 21, loss = 1.410315752029419
# Checking accuracy on test set
# Got 4480 / 10000 correct (44.80)
# Checking accuracy on train set
# Got 29480 / 50000 correct (58.96)
#
# Epoch 22, loss = 1.0157458782196045
# Checking accuracy on test set
# Got 4507 / 10000 correct (45.07)
# Checking accuracy on train set
# Got 30947 / 50000 correct (61.89)
#
# Epoch 23, loss = 1.2138525247573853
# Checking accuracy on test set
# Got 4487 / 10000 correct (44.87)
# Checking accuracy on train set
# Got 31677 / 50000 correct (63.35)
#
# Epoch 24, loss = 0.8746058940887451
# Checking accuracy on test set
# Got 4484 / 10000 correct (44.84)
# Checking accuracy on train set
# Got 32118 / 50000 correct (64.24)
#
# Epoch 25, loss = 1.4569287300109863
# Checking accuracy on test set
# Got 4489 / 10000 correct (44.89)
# Checking accuracy on train set
# Got 32787 / 50000 correct (65.57)
#
# Epoch 26, loss = 0.7976102232933044
# Checking accuracy on test set
# Got 4460 / 10000 correct (44.60)
# Checking accuracy on train set
# Got 32926 / 50000 correct (65.85)
#
# Epoch 27, loss = 1.150310754776001
# Checking accuracy on test set
# Got 4441 / 10000 correct (44.41)
# Checking accuracy on train set
# Got 33606 / 50000 correct (67.21)
#
# Epoch 28, loss = 1.1728559732437134
# Checking accuracy on test set
# Got 4460 / 10000 correct (44.60)
# Checking accuracy on train set
# Got 34827 / 50000 correct (69.65)
#
# Epoch 29, loss = 0.9633452892303467
# Checking accuracy on test set
# Got 4550 / 10000 correct (45.50)
# Checking accuracy on train set
# Got 34995 / 50000 correct (69.99)
#
# Epoch 30, loss = 0.6101059913635254
# Checking accuracy on test set
# Got 4391 / 10000 correct (43.91)
# Checking accuracy on train set
# Got 34735 / 50000 correct (69.47)
#
# Epoch 31, loss = 1.449317455291748
# Checking accuracy on test set
# Got 4414 / 10000 correct (44.14)
# Checking accuracy on train set
# Got 35075 / 50000 correct (70.15)
#
# Epoch 32, loss = 0.7247230410575867
# Checking accuracy on test set
# Got 4454 / 10000 correct (44.54)
# Checking accuracy on train set
# Got 36659 / 50000 correct (73.32)
#
# Epoch 33, loss = 0.7685291767120361
# Checking accuracy on test set
# Got 4435 / 10000 correct (44.35)
# Checking accuracy on train set
# Got 36660 / 50000 correct (73.32)
#
# Epoch 34, loss = 1.622363567352295
# Checking accuracy on test set
# Got 4536 / 10000 correct (45.36)
# Checking accuracy on train set
# Got 37438 / 50000 correct (74.88)
#
# Epoch 35, loss = 0.6218164563179016
# Checking accuracy on test set
# Got 4453 / 10000 correct (44.53)
# Checking accuracy on train set
# Got 38373 / 50000 correct (76.75)
#
# Epoch 36, loss = 0.683046281337738
# Checking accuracy on test set
# Got 4456 / 10000 correct (44.56)
# Checking accuracy on train set
# Got 38295 / 50000 correct (76.59)
#
# Epoch 37, loss = 1.0528857707977295
# Checking accuracy on test set
# Got 4465 / 10000 correct (44.65)
# Checking accuracy on train set
# Got 39168 / 50000 correct (78.34)
#
# Epoch 38, loss = 0.8293694853782654
# Checking accuracy on test set
# Got 4511 / 10000 correct (45.11)
# Checking accuracy on train set
# Got 40498 / 50000 correct (81.00)
#
# Epoch 39, loss = 0.5578962564468384
# Checking accuracy on test set
# Got 4492 / 10000 correct (44.92)
# Checking accuracy on train set
# Got 40634 / 50000 correct (81.27)
#
# Epoch 40, loss = 0.4709475636482239
# Checking accuracy on test set
# Got 4537 / 10000 correct (45.37)
# Checking accuracy on train set
# Got 41218 / 50000 correct (82.44)
#
# Epoch 41, loss = 0.21728549897670746
# Checking accuracy on test set
# Got 4544 / 10000 correct (45.44)
# Checking accuracy on train set
# Got 41662 / 50000 correct (83.32)
#
# Epoch 42, loss = 0.5232900381088257
# Checking accuracy on test set
# Got 4498 / 10000 correct (44.98)
# Checking accuracy on train set
# Got 41667 / 50000 correct (83.33)
#
# Epoch 43, loss = 0.7812880277633667
# Checking accuracy on test set
# Got 4413 / 10000 correct (44.13)
# Checking accuracy on train set
# Got 42344 / 50000 correct (84.69)
#
# Epoch 44, loss = 0.5686139464378357
# Checking accuracy on test set
# Got 4496 / 10000 correct (44.96)
# Checking accuracy on train set
# Got 42866 / 50000 correct (85.73)
#
# Epoch 45, loss = 0.2102140188217163
# Checking accuracy on test set
# Got 4499 / 10000 correct (44.99)
# Checking accuracy on train set
# Got 42768 / 50000 correct (85.54)
#
# Epoch 46, loss = 0.8725463151931763
# Checking accuracy on test set
# Got 4293 / 10000 correct (42.93)
# Checking accuracy on train set
# Got 41718 / 50000 correct (83.44)
#
# Epoch 47, loss = 0.41395050287246704
# Checking accuracy on test set
# Got 4488 / 10000 correct (44.88)
# Checking accuracy on train set
# Got 43700 / 50000 correct (87.40)
#
# Epoch 48, loss = 0.384169340133667
# Checking accuracy on test set
# Got 4432 / 10000 correct (44.32)
# Checking accuracy on train set
# Got 43505 / 50000 correct (87.01)
#
# Epoch 49, loss = 0.21913576126098633
# Checking accuracy on test set
# Got 4466 / 10000 correct (44.66)
# Checking accuracy on train set
# Got 44406 / 50000 correct (88.81)

# %%
from scipy import stats, fft

class CIFARDataset(torch.utils.data.Dataset):
    def __init__(self, train, dataset_path='/cifar10', freq_radius = 128):
        self.dataset = torchvision.datasets.CIFAR10(root='./data', train=train,
                                        download=True)
        self.freq_radius = freq_radius
        self.train = train

    def __getitem__(self, index):
        (img, label) = self.dataset[index]
        transformed_img = np.mean(np.array(img), axis = -1)           # convert into grayscale
        transformed_img = np.reshape(transformed_img, (1024, ))
        transformed_img = fft.dct(transformed_img, type = 2)
        transformed_img = np.concatenate((transformed_img[-self.freq_radius:], transformed_img[:self.freq_radius]))
        transformed_img = stats.zscore(transformed_img)
        return torch.from_numpy(transformed_img), label

    def __len__(self):
        return len(self.dataset)

dct_trainset = CIFARDataset(train = True)
dct_trainloader = torch.utils.data.DataLoader(dct_trainset, batch_size=64,
                                          shuffle=True)

dct_testset = CIFARDataset(train = False)
dct_testloader = torch.utils.data.DataLoader(dct_testset, batch_size=64,
                                         shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def dct_check_accuracy(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on train set')
    else:
        print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

test_accuracies = []
train_accuracies = []

def dct_train(model, optimizer, epochs=10):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(dct_trainloader):
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

        print(f'Epoch {e}, loss = {loss.item()}')
        test_accuracies.append(dct_check_accuracy(dct_testloader, model))
        train_accuracies.append(dct_check_accuracy(dct_trainloader, model))
        print()

# %%
learning_rate = 0.001

dct_model = nn.Sequential(
    Flatten(),
    nn.Linear(256, 256),
    nn.ReLU(),
    nn.Linear(256, 256),
    nn.ReLU(),
    nn.Linear(256, 10)
)

optimizer = optim.SGD(dct_model.parameters(), lr=learning_rate, momentum=0.9, nesterov=True)
dct_train(dct_model, optimizer, epochs = 50)
# Out:
# Epoch 0, loss = 2.216207504272461
# Checking accuracy on test set
# Got 2044 / 10000 correct (20.44)
# Checking accuracy on train set
# Got 10249 / 50000 correct (20.50)
#
# Epoch 1, loss = 2.362769365310669
# Checking accuracy on test set
# Got 2136 / 10000 correct (21.36)
# Checking accuracy on train set
# Got 10928 / 50000 correct (21.86)
#
# Epoch 2, loss = 1.9851371049880981
# Checking accuracy on test set
# Got 2430 / 10000 correct (24.30)
# Checking accuracy on train set
# Got 12310 / 50000 correct (24.62)
#
# Epoch 3, loss = 2.097755193710327
# Checking accuracy on test set
# Got 2574 / 10000 correct (25.74)
# Checking accuracy on train set
# Got 12984 / 50000 correct (25.97)
#
# Epoch 4, loss = 1.872762680053711
# Checking accuracy on test set
# Got 2637 / 10000 correct (26.37)
# Checking accuracy on train set
# Got 13397 / 50000 correct (26.79)
#
# Epoch 5, loss = 1.942753553390503
# Checking accuracy on test set
# Got 2720 / 10000 correct (27.20)
# Checking accuracy on train set
# Got 13923 / 50000 correct (27.85)
#
# Epoch 6, loss = 1.944246768951416
# Checking accuracy on test set
# Got 2794 / 10000 correct (27.94)
# Checking accuracy on train set
# Got 14231 / 50000 correct (28.46)
#
# Epoch 7, loss = 1.7431576251983643
# Checking accuracy on test set
# Got 2860 / 10000 correct (28.60)
# Checking accuracy on train set
# Got 14439 / 50000 correct (28.88)
#
# Epoch 8, loss = 1.953674554824829
# Checking accuracy on test set
# Got 2978 / 10000 correct (29.78)
# Checking accuracy on train set
# Got 14929 / 50000 correct (29.86)
#
# Epoch 9, loss = 1.8382445573806763
# Checking accuracy on test set
# Got 3062 / 10000 correct (30.62)
# Checking accuracy on train set
# Got 15386 / 50000 correct (30.77)
#
# Epoch 10, loss = 2.006258964538574
# Checking accuracy on test set
# Got 3069 / 10000 correct (30.69)
# Checking accuracy on train set
# Got 15454 / 50000 correct (30.91)
#
# Epoch 11, loss = 1.648997187614441
# Checking accuracy on test set
# Got 3201 / 10000 correct (32.01)
# Checking accuracy on train set
# Got 15887 / 50000 correct (31.77)
#
# Epoch 12, loss = 2.080441951751709
# Checking accuracy on test set
# Got 3206 / 10000 correct (32.06)
# Checking accuracy on train set
# Got 16099 / 50000 correct (32.20)
#
# Epoch 13, loss = 1.5512208938598633
# Checking accuracy on test set
# Got 3301 / 10000 correct (33.01)
# Checking accuracy on train set
# Got 16510 / 50000 correct (33.02)
#
# Epoch 14, loss = 1.7885875701904297
# Checking accuracy on test set
# Got 3312 / 10000 correct (33.12)
# Checking accuracy on train set
# Got 16662 / 50000 correct (33.32)
#
# Epoch 15, loss = 1.8428250551223755
# Checking accuracy on test set
# Got 3315 / 10000 correct (33.15)
# Checking accuracy on train set
# Got 16910 / 50000 correct (33.82)
#
# Epoch 16, loss = 2.032196283340454
# Checking accuracy on test set
# Got 3385 / 10000 correct (33.85)
# Checking accuracy on train set
# Got 17032 / 50000 correct (34.06)
#
# Epoch 17, loss = 2.04603910446167
# Checking accuracy on test set
# Got 3470 / 10000 correct (34.70)
# Checking accuracy on train set
# Got 17247 / 50000 correct (34.49)
#
# Epoch 18, loss = 1.6009516716003418
# Checking accuracy on test set
# Got 3420 / 10000 correct (34.20)
# Checking accuracy on train set
# Got 17319 / 50000 correct (34.64)
#
# Epoch 19, loss = 2.3485164642333984
# Checking accuracy on test set
# Got 3517 / 10000 correct (35.17)
# Checking accuracy on train set
# Got 17624 / 50000 correct (35.25)
#
# Epoch 20, loss = 2.0592615604400635
# Checking accuracy on test set
# Got 3530 / 10000 correct (35.30)
# Checking accuracy on train set
# Got 17731 / 50000 correct (35.46)
#
# Epoch 21, loss = 2.4786815643310547
# Checking accuracy on test set
# Got 3451 / 10000 correct (34.51)
# Checking accuracy on train set
# Got 17512 / 50000 correct (35.02)
#
# Epoch 22, loss = 1.7530440092086792
# Checking accuracy on test set
# Got 3545 / 10000 correct (35.45)
# Checking accuracy on train set
# Got 18028 / 50000 correct (36.06)
#
# Epoch 23, loss = 1.6415274143218994
# Checking accuracy on test set
# Got 3632 / 10000 correct (36.32)
# Checking accuracy on train set
# Got 18281 / 50000 correct (36.56)
#
# Epoch 24, loss = 2.0191664695739746
# Checking accuracy on test set
# Got 3615 / 10000 correct (36.15)
# Checking accuracy on train set
# Got 18270 / 50000 correct (36.54)
#
# Epoch 25, loss = 1.8271158933639526
# Checking accuracy on test set
# Got 3548 / 10000 correct (35.48)
# Checking accuracy on train set
# Got 18133 / 50000 correct (36.27)
#
# Epoch 26, loss = 1.991767406463623
# Checking accuracy on test set
# Got 3484 / 10000 correct (34.84)
# Checking accuracy on train set
# Got 18002 / 50000 correct (36.00)
#
# Epoch 27, loss = 1.6985849142074585
# Checking accuracy on test set
# Got 3702 / 10000 correct (37.02)
# Checking accuracy on train set
# Got 18866 / 50000 correct (37.73)
#
# Epoch 28, loss = 1.6310738325119019
# Checking accuracy on test set
# Got 3701 / 10000 correct (37.01)
# Checking accuracy on train set
# Got 18896 / 50000 correct (37.79)
#
# Epoch 29, loss = 1.9765723943710327
# Checking accuracy on test set
# Got 3703 / 10000 correct (37.03)
# Checking accuracy on train set
# Got 18885 / 50000 correct (37.77)
#
# Epoch 30, loss = 1.945515751838684
# Checking accuracy on test set
# Got 3711 / 10000 correct (37.11)
# Checking accuracy on train set
# Got 18806 / 50000 correct (37.61)
#
# Epoch 31, loss = 1.9678045511245728
# Checking accuracy on test set
# Got 3636 / 10000 correct (36.36)
# Checking accuracy on train set
# Got 18931 / 50000 correct (37.86)
#
# Epoch 32, loss = 1.7852783203125
# Checking accuracy on test set
# Got 3720 / 10000 correct (37.20)
# Checking accuracy on train set
# Got 19121 / 50000 correct (38.24)
#
# Epoch 33, loss = 2.0494399070739746
# Checking accuracy on test set
# Got 3800 / 10000 correct (38.00)
# Checking accuracy on train set
# Got 19415 / 50000 correct (38.83)
#
# Epoch 34, loss = 1.7984405755996704
# Checking accuracy on test set
# Got 3656 / 10000 correct (36.56)
# Checking accuracy on train set
# Got 19069 / 50000 correct (38.14)
#
# Epoch 35, loss = 1.3540180921554565
# Checking accuracy on test set
# Got 3774 / 10000 correct (37.74)
# Checking accuracy on train set
# Got 19425 / 50000 correct (38.85)
#
# Epoch 36, loss = 1.9239860773086548
# Checking accuracy on test set
# Got 3774 / 10000 correct (37.74)
# Checking accuracy on train set
# Got 19437 / 50000 correct (38.87)
#
# Epoch 37, loss = 1.9435410499572754
# Checking accuracy on test set
# Got 3824 / 10000 correct (38.24)
# Checking accuracy on train set
# Got 19626 / 50000 correct (39.25)
#
# Epoch 38, loss = 1.628603458404541
# Checking accuracy on test set
# Got 3806 / 10000 correct (38.06)
# Checking accuracy on train set
# Got 19739 / 50000 correct (39.48)
#
# Epoch 39, loss = 1.4258259534835815
# Checking accuracy on test set
# Got 3794 / 10000 correct (37.94)
# Checking accuracy on train set
# Got 19641 / 50000 correct (39.28)
#
# Epoch 40, loss = 1.565604329109192
# Checking accuracy on test set
# Got 3841 / 10000 correct (38.41)
# Checking accuracy on train set
# Got 19917 / 50000 correct (39.83)
#
# Epoch 41, loss = 1.664044737815857
# Checking accuracy on test set
# Got 3843 / 10000 correct (38.43)
# Checking accuracy on train set
# Got 20074 / 50000 correct (40.15)
#
# Epoch 42, loss = 1.7155652046203613
# Checking accuracy on test set
# Got 3824 / 10000 correct (38.24)
# Checking accuracy on train set
# Got 19699 / 50000 correct (39.40)
#
# Epoch 43, loss = 1.8704259395599365
# Checking accuracy on test set
# Got 3864 / 10000 correct (38.64)
# Checking accuracy on train set
# Got 20126 / 50000 correct (40.25)
#
# Epoch 44, loss = 1.8904109001159668
# Checking accuracy on test set
# Got 3813 / 10000 correct (38.13)
# Checking accuracy on train set
# Got 20024 / 50000 correct (40.05)
#
# Epoch 45, loss = 2.1715636253356934
# Checking accuracy on test set
# Got 3928 / 10000 correct (39.28)
# Checking accuracy on train set
# Got 20387 / 50000 correct (40.77)
#
# Epoch 46, loss = 1.5216121673583984
# Checking accuracy on test set
# Got 3858 / 10000 correct (38.58)
# Checking accuracy on train set
# Got 20431 / 50000 correct (40.86)
#
# Epoch 47, loss = 1.636027216911316
# Checking accuracy on test set
# Got 3892 / 10000 correct (38.92)
# Checking accuracy on train set
# Got 20466 / 50000 correct (40.93)
#
# Epoch 48, loss = 1.3010812997817993
# Checking accuracy on test set
# Got 3952 / 10000 correct (39.52)
# Checking accuracy on train set
# Got 20786 / 50000 correct (41.57)
#
# Epoch 49, loss = 1.9059221744537354
# Checking accuracy on test set
# Got 3904 / 10000 correct (39.04)
# Checking accuracy on train set
# Got 20470 / 50000 correct (40.94)

# %%
learning_rate = 3e-4

optimizer = optim.SGD(dct_model.parameters(), lr=learning_rate, momentum=0.9, nesterov=True)
dct_train(dct_model, optimizer, epochs = 150)
# Out:
# Epoch 0, loss = 1.3866915702819824
# Checking accuracy on test set
# Got 3978 / 10000 correct (39.78)
# Checking accuracy on train set
# Got 21087 / 50000 correct (42.17)
#
# Epoch 1, loss = 1.8054126501083374
# Checking accuracy on test set
# Got 4001 / 10000 correct (40.01)
# Checking accuracy on train set
# Got 21073 / 50000 correct (42.15)
#
# Epoch 2, loss = 1.5109609365463257
# Checking accuracy on test set
# Got 3962 / 10000 correct (39.62)
# Checking accuracy on train set
# Got 21117 / 50000 correct (42.23)
#
# Epoch 3, loss = 1.5482374429702759
# Checking accuracy on test set
# Got 4022 / 10000 correct (40.22)
# Checking accuracy on train set
# Got 21246 / 50000 correct (42.49)
#
# Epoch 4, loss = 1.5881743431091309
# Checking accuracy on test set
# Got 3972 / 10000 correct (39.72)
# Checking accuracy on train set
# Got 21001 / 50000 correct (42.00)
#
# Epoch 5, loss = 1.5952140092849731
# Checking accuracy on test set
# Got 3982 / 10000 correct (39.82)
# Checking accuracy on train set
# Got 21165 / 50000 correct (42.33)
#
# Epoch 6, loss = 1.5214110612869263
# Checking accuracy on test set
# Got 4025 / 10000 correct (40.25)
# Checking accuracy on train set
# Got 21298 / 50000 correct (42.60)
#
# Epoch 7, loss = 2.0249710083007812
# Checking accuracy on test set
# Got 4027 / 10000 correct (40.27)
# Checking accuracy on train set
# Got 21320 / 50000 correct (42.64)
#
# Epoch 8, loss = 1.8268486261367798
# Checking accuracy on test set
# Got 4000 / 10000 correct (40.00)
# Checking accuracy on train set
# Got 21207 / 50000 correct (42.41)
#
# Epoch 9, loss = 1.6798709630966187
# Checking accuracy on test set
# Got 4062 / 10000 correct (40.62)
# Checking accuracy on train set
# Got 21403 / 50000 correct (42.81)
#
# Epoch 10, loss = 1.4297016859054565
# Checking accuracy on test set
# Got 4020 / 10000 correct (40.20)
# Checking accuracy on train set
# Got 21282 / 50000 correct (42.56)
#
# Epoch 11, loss = 1.5399094820022583
# Checking accuracy on test set
# Got 4030 / 10000 correct (40.30)
# Checking accuracy on train set
# Got 21350 / 50000 correct (42.70)
#
# Epoch 12, loss = 1.7654887437820435
# Checking accuracy on test set
# Got 3991 / 10000 correct (39.91)
# Checking accuracy on train set
# Got 21266 / 50000 correct (42.53)
#
# Epoch 13, loss = 1.6181862354278564
# Checking accuracy on test set
# Got 4016 / 10000 correct (40.16)
# Checking accuracy on train set
# Got 21465 / 50000 correct (42.93)
#
# Epoch 14, loss = 1.347375750541687
# Checking accuracy on test set
# Got 4043 / 10000 correct (40.43)
# Checking accuracy on train set
# Got 21459 / 50000 correct (42.92)
#
# Epoch 15, loss = 1.7489427328109741
# Checking accuracy on test set
# Got 4027 / 10000 correct (40.27)
# Checking accuracy on train set
# Got 21454 / 50000 correct (42.91)
#
# Epoch 16, loss = 2.0697693824768066
# Checking accuracy on test set
# Got 4032 / 10000 correct (40.32)
# Checking accuracy on train set
# Got 21537 / 50000 correct (43.07)
#
# Epoch 17, loss = 1.7836813926696777
# Checking accuracy on test set
# Got 4027 / 10000 correct (40.27)
# Checking accuracy on train set
